# %%
from sim_pipeline.Halos.halos_plus_glass import run_kappaext_gammaext_kde_by_multiprocessing

distri =run_kappaext_gammaext_kde_by_multiprocessing(n_iterations=1,output_format='vector')
# Out:
# C:\Users\TXZ27\OneDrive\Documents\GitHub\sim-pipeline\sim_pipeline\Halos\halos_plus_glass.py:478: UserWarning: No cosmology provided, instead uses astropy.cosmology default cosmology
#   warnings.warn("No cosmology provided, instead uses astropy.cosmology default cosmology")
# The 1 halo-lists took 51.52994751930237 seconds to run

# %%
print(len(distri))
print(distri)
# Out:
# 1274
# ...
