# %%
from slsim.Halos.halos_plus_glass import run_halos_without_kde_by_multiprocessing
import numpy as np
from astropy.cosmology import FlatLambdaCDM
# Out:
# C:\Users\TXZ27\AppData\Local\Programs\Python\Python310\lib\site-packages\numba\core\decorators.py:262: NumbaDeprecationWarning: numba.generated_jit is deprecated. Please see the documentation at: https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-generated-jit for more information and advice on a suitable replacement.
#   warnings.warn(msg, NumbaDeprecationWarning)

# %%
cosmo = FlatLambdaCDM(H0=70, Om0=0.3)

nk,ng = run_halos_without_kde_by_multiprocessing(n_iterations=50, sky_area=0.0001, samples_number=2,cosmo=cosmo,  m_min=1.5E+11, m_max=None, z_max=1.5)
# Out:
# The 50 halo-lists took 30.433361053466797 seconds to run

# %%
import seaborn as sns
import matplotlib.pyplot as plt

total_plot = sns.jointplot(x=nk, y=ng,kind='hex')
total_plot.plot_joint(sns.kdeplot, color="r", zorder=3, levels=5)
total_plot.ax_joint.set_xlabel('kappa', fontweight='bold')
total_plot.ax_joint.set_ylabel('gamma', fontweight='bold')
total_plot.fig.suptitle("Kappa and Gamma values without correction")
plt.show()

# %%
from slsim.Halos.halos_lens import HalosLens
from slsim.Halos.halos_plus_glass import run_certain_redshift_lensext_kde_by_multiprocessing
from astropy.cosmology import FlatLambdaCDM
cosmo = FlatLambdaCDM(H0=70, Om0=0.3)
distribution = run_certain_redshift_lensext_kde_by_multiprocessing(n_iterations=50, sky_area=0.0001, samples_number=2,cosmo=cosmo,  m_min=1.5E+11, m_max=None, z_max=1.5, zs=1.5, zd=0.5)

print(distribution)
# Out:
# The 50 halo-lists took 94.2428925037384 seconds to run
# [array([-0.02343467,  0.00668295]), array([-0.03233528,  0.00259398]), array([-0.00849222,  0.01874485]), array([-0.01825914,  0.01011905]), array([0.0589268 , 0.04177696]), array([0.08123184, 0.03190782]), array([-0.01873464,  0.00887103]), array([0.01385113, 0.02341708]), array([0.00073208, 0.00555625]), array([-0.01027145,  0.00566802]), array([-0.03293394,  0.00183842]), array([-0.03285988,  0.00137829]), array([0.01855273, 0.01938225]), array([0.02132294, 0.01478643]), array([0.02920209, 0.02771596]), array([0.06817525, 0.00472419]), array([-0.03637674,  0.00260334]), array([-0.03785561,  0.00073685]), array([-0.01170211,  0.01987155]), array([-0.00258637,  0.01080492]), array([-0.0231234 ,  0.00660791]), array([-0.02569315,  0.00579194]), array([-0.02088955,  0.01124231]), array([-0.02776989,  0.00097391]), array([0.10401284, 0.04500575]), array([0.0475587, 0.0181445]), array([-0.01248504,  0.02329211]), array([0.01160301, 0.00866595]), array([0.07376407, 0.00567989]), array([0.09294133, 0.03006114]), array([-0.02756924,  0.00455992]), array([-0.02367068,  0.01053928]), array([-0.02822692,  0.0046567 ]), array([-0.02813667,  0.00838888]), array([-0.0278971 ,  0.00621209]), array([0.02150031, 0.0048041 ]), array([0.02869387, 0.03184739]), array([0.01655566, 0.0265481 ]), array([-0.01870811,  0.00528187]), array([-0.02722953,  0.00415271]), array([-0.02834481,  0.00527681]), array([-0.03085287,  0.00322295]), array([-0.0015239 ,  0.00928561]), array([-0.00145231,  0.0126366 ]), array([-0.01334891,  0.00981962]), array([-0.01254365,  0.00423857]), array([-0.03895339,  0.00015407]), array([-0.03772389,  0.00124281]), array([-0.0113591 ,  0.00922849]), array([0.00039867, 0.02326793]), array([0.02348879, 0.01001583]), array([0.03157227, 0.01306879]), array([-0.03178006,  0.00768752]), array([-0.03295057,  0.0032778 ]), array([0.02892904, 0.0373055 ]), array([-0.00289562,  0.00936555]), array([-0.00600913,  0.02374186]), array([-0.00709246,  0.01059815]), array([0.09439563, 0.02038101]), array([0.06598885, 0.00584879]), array([-0.02930169,  0.00297069]), array([-0.02598566,  0.00322605]), array([-0.03862001,  0.00108061]), array([-0.0383725 ,  0.00091969]), array([-0.00980824,  0.00622163]), array([-0.02308705,  0.01250234]), array([-0.02034563,  0.00429185]), array([-0.02758345,  0.00364107]), array([-0.01097637,  0.01602847]), array([-0.01806726,  0.00533338]), array([-0.02310021,  0.00460977]), array([-0.01748165,  0.00806816]), array([0.04398049, 0.00649932]), array([0.05335139, 0.0052204 ]), array([-0.02397901,  0.00131274]), array([-0.03211842,  0.00295229]), array([-0.00091844,  0.01465887]), array([-0.01708123,  0.00152926]), array([-0.03165269,  0.00218846]), array([-0.03583537,  0.00277692]), array([-0.01816924,  0.00118278]), array([-0.0231547 ,  0.00460812]), array([-0.03020201,  0.00065685]), array([-0.02884797,  0.00174427]), array([-0.0071174 ,  0.01116645]), array([-0.00688369,  0.01414735]), array([-0.02000456,  0.00475416]), array([-0.02490365,  0.00555452]), array([-0.02075686,  0.01113973]), array([-0.00734256,  0.01675947]), array([-0.02798944,  0.00433894]), array([-0.02847803,  0.00547677]), array([0.00056637, 0.00543823]), array([-0.00810158,  0.00625744]), array([-0.01354002,  0.00418948]), array([-0.01810306,  0.00604575]), array([-0.00977534,  0.01217104]), array([-0.02157266,  0.0057877 ]), array([-0.02338478,  0.00258228]), array([-0.01481649,  0.01355893])]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

nk1 = [point[0] for point in distribution]
ng1 = [point[1] for point in distribution]

total_plot = sns.jointplot(x=nk1, y=ng1,kind='hex')
total_plot.plot_joint(sns.kdeplot, color="r", zorder=3, levels=5)
total_plot.ax_joint.set_xlabel('kappa', fontweight='bold')
total_plot.ax_joint.set_ylabel('gamma', fontweight='bold')
total_plot.fig.suptitle("Kappa and Gamma values with correction")
plt.show()

# %%
cosmo = FlatLambdaCDM(H0=70, Om0=0.3)

nk,ng = run_halos_without_kde_by_multiprocessing(n_iterations=70, sky_area=0.0001, samples_number=2,cosmo=cosmo,  m_min=5E+10, m_max=None, z_max=1.5)
import seaborn as sns
import matplotlib.pyplot as plt

total_plot = sns.jointplot(x=nk, y=ng,kind='hex')
total_plot.plot_joint(sns.kdeplot, color="r", zorder=3, levels=5)
total_plot.ax_joint.set_xlabel('kappa', fontweight='bold')
total_plot.ax_joint.set_ylabel('gamma', fontweight='bold')
total_plot.fig.suptitle("Kappa and Gamma values without correction")
plt.show()

from sim_pipeline.Halos.halos_plus_glass import run_certain_redshift_lensext_kde_by_multiprocessing
from astropy.cosmology import FlatLambdaCDM
cosmo = FlatLambdaCDM(H0=70, Om0=0.3)
distribution = run_certain_redshift_lensext_kde_by_multiprocessing(n_iterations=70, sky_area=0.0001, samples_number=2,cosmo=cosmo,  m_min=5E+10, m_max=None, z_max=1.5, zs=1.5, zd=0.5)

nk1 = [point[0] for point in distribution]
ng1 = [point[1] for point in distribution]

total_plot = sns.jointplot(x=nk1, y=ng1,kind='hex')
total_plot.plot_joint(sns.kdeplot, color="r", zorder=3, levels=5)
total_plot.ax_joint.set_xlabel('kappa', fontweight='bold')
total_plot.ax_joint.set_ylabel('gamma', fontweight='bold')
total_plot.fig.suptitle("Kappa and Gamma values with correction")
plt.show()
# Out:
# The 70 halo-lists took 195.87421226501465 seconds to run
# The 70 halo-lists took 218.99806904792786 seconds to run

# %%
print(distribution)
# Out:
), array([0.23771861, 0.0278579 ]), array([0.04032553, 0.01606479]), array([-6.65430273e-05,  9.01373096e-03]), array([-0.0253283 ,  0.00292085]), array([-0.02180467,  0.00409483]), array([0.00170995, 0.01232922]), array([-0.02167496,  0.00236839]), array([0.07564755, 0.01458461]), array([0.09324533, 0.02075273]), array([-0.01932533,  0.00868552]), array([-0.02236756,  0.00659395]), array ...

# %%
import pandas as pd

df1 = pd.DataFrame({'x': nk, 'y': ng, 'type': 'Without Correction'})
df2 = pd.DataFrame({'x': nk1, 'y': ng1, 'type': 'With LOS Correction'})

# Concatenate DataFrames
df_total = pd.concat([df1, df2], axis=0)

import seaborn as sns

sns.jointplot(data=df_total, x="x", y="y", hue="type", kind="kde")
plt.title('z_max=1.5, zs=1.5')
plt.show()

# %%
import pandas as pd
import numpy as np
from slsim.Halos.halos_plus_glass import run_halos_without_kde_by_multiprocessing, run_certain_redshift_lensext_kde_by_multiprocessing
from astropy.cosmology import FlatLambdaCDM,default_cosmology
import seaborn as sns
import matplotlib.pyplot as plt

def plot_kappa_gamma(zs=1.5, zd=0.5, n_iterations=100, sky_area=0.0001, samples_number=30, m_min='1.0E+12', m_max='1.0E+16'):
    # Setup Cosmology
    cosmo = default_cosmology.get()
    # Without Correction
    nk, ng = run_halos_without_kde_by_multiprocessing(n_iterations=n_iterations, sky_area=sky_area, samples_number=samples_number, cosmo=cosmo, m_min=m_min, m_max=m_max, z_max=zs, listmean=True)
    nk_mean = sum(nk) / len(nk)
    print(f"zs={zs}, zd={zd},k_s_mean={nk_mean}")
    nk = [item - nk_mean for item in nk]

    # With Correction
    distribution = run_certain_redshift_lensext_kde_by_multiprocessing(n_iterations=n_iterations, sky_area=sky_area, samples_number=samples_number, cosmo=cosmo, m_min=m_min, m_max=m_max, z_max=zs, zs=zs, zd=zd, listmean=True)
    nk1 = [point[0] for point in distribution]
    ng1 = [point[1] for point in distribution]
    nk1_mean = sum(nk1) / len(nk1)
    print(f"zs={zs}, zd={zd},k_ext_mean={nk1_mean}")
    nk1 = [item - nk1_mean for item in nk1]


    # Combine Data for Joint KDE Plot
    df1 = pd.DataFrame({'x': nk, 'y': ng, 'type': 'Without Correction'})
    df2 = pd.DataFrame({'x': nk1, 'y': ng1, 'type': 'With LOS Correction'})
    df_total = pd.concat([df1, df2], axis=0)

    var_nk = np.var(nk)
    var_nk1 = np.var(nk1)
    print(f"Variance of k_S: {var_nk}")
    print(f"Variance of k_ext: {var_nk1}")

    # Plotting
    plot = sns.jointplot(data=df_total, x="x", y="y", hue="type", kind="kde")

    plot.ax_joint.set_xlabel("kappa")
    plot.ax_joint.set_ylabel("gamma")
    m_min_float = float(m_min)
    plt.title(f'zs={zs}, zd={zd}, mean=0')
    plot.fig.suptitle(f"zs={zs}, zd={zd}, m=10^{np.log10(m_min_float)}, mean=0, with mass-sheet")
   # plot.ax_joint.set_xlim(-0.2, 0.2)

    plt.show()

# To use the function:
plot_kappa_gamma(zs=1.5, zd=0.5,m_min='1.0E+12', m_max='1.0E+16')
plot_kappa_gamma(zs=1.5, zd=0.5,m_min='1.0E+12', m_max='1.0E+16')
plot_kappa_gamma(zs=1.5, zd=0.5,m_min='1.0E+12', m_max='1.0E+16')
# Out:
# The 100 halo-lists took 42.48183059692383 seconds to run
# zs=1.5, zd=0.5,k_s_mean=-7.864079757761525e-19
# The 100 halo-lists took 79.02076840400696 seconds to run
# zs=1.5, zd=0.5,k_ext_mean=6.013708050052931e-20
# Variance of k_S: 0.0009125420524631774
# Variance of k_ext: 0.0005744150673980769
# The 100 halo-lists took 53.0802001953125 seconds to run
# zs=1.5, zd=0.5,k_s_mean=2.8356946420634207e-18
# The 100 halo-lists took 74.21614980697632 seconds to run
# zs=1.5, zd=0.5,k_ext_mean=7.216449660063517e-19
# Variance of k_S: 0.0006669102385231156
# Variance of k_ext: 0.0004622618787733054
# The 100 halo-lists took 45.48516607284546 seconds to run
# zs=1.5, zd=0.5,k_s_mean=-2.447116583444616e-18
# The 100 halo-lists took 76.92946314811707 seconds to run
# zs=1.5, zd=0.5,k_ext_mean=1.878127283324223e-18
# Variance of k_S: 0.0006275445044466346
# Variance of k_ext: 0.00039509803448759434

# %%
import pandas as pd
from slsim.Halos.halos_plus_glass import run_halos_without_kde_by_multiprocessing, run_certain_redshift_lensext_kde_by_multiprocessing
from astropy.cosmology import FlatLambdaCDM,default_cosmology
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

def plot_kappa_gamma2(zs=1.5, zd=0.5, n_iterations=180, sky_area=0.0001, samples_number=40, m_min='1E+12', m_max='1E+16'):
    # Setup Cosmology
    cosmo = default_cosmology.get()
    # Without Correction
    nk, ng = run_halos_without_kde_by_multiprocessing(n_iterations=n_iterations, sky_area=sky_area, samples_number=samples_number, cosmo=cosmo, m_min=m_min, m_max=m_max, z_max=zs,mass_sheet_correction=False, listmean=True)
    nk_mean = sum(nk) / len(nk)
    nk = [item - nk_mean for item in nk]
    
    # With Correction
    distribution = run_certain_redshift_lensext_kde_by_multiprocessing(n_iterations=n_iterations, sky_area=sky_area, samples_number=samples_number, cosmo=cosmo, m_min=m_min, m_max=m_max, z_max=zs, zs=zs, zd=zd,mass_sheet_correction=False, listmean=True)
    nk1 = [point[0] for point in distribution]
    ng1 = [point[1] for point in distribution]
    nk1_mean = sum(nk1) / len(nk1)
    nk1 = [item - nk1_mean for item in nk1]
    
    
    # Combine Data for Joint KDE Plot
    df1 = pd.DataFrame({'x': nk, 'y': ng, 'type': 'Without Correction'})
    df2 = pd.DataFrame({'x': nk1, 'y': ng1, 'type': 'With LOS Correction'})
    df_total = pd.concat([df1, df2], axis=0)
    m_min_float = float(m_min)

    # Plotting
    plot = sns.jointplot(data=df_total, x="x", y="y",  hue="type", kind="kde")
    plot.fig.suptitle(f"zs={zs}, zd={zd},, m=10^{np.log10(m_min_float)}, mean=0, without mass-sheet")
    plot.ax_joint.set_xlim(-0.2, 0.2)
    plt.show()

# %%
plot_kappa_gamma2(zs=2.5, zd=1.0, m_min='1.0E+12', m_max='1.0E+16')

#plot_kappa_gamma2(zs=3.5, zd=1.5, m_min='1.0E+12', m_max='1.0E+16')

plot_kappa_gamma2(zs=1.5, zd=1.0, m_min='1.0E+12', m_max='1.0E+16')
# Out:
# The 180 halo-lists took 122.9480230808258 seconds to run
# The 180 halo-lists took 256.92270040512085 seconds to run
# The 180 halo-lists took 144.46734809875488 seconds to run
# The 180 halo-lists took 197.09132885932922 seconds to run

# %%
plot_kappa_gamma2(zs=4.5, zd=1.5, m_min='1.0E+12', m_max='1.0E+16')
# Out:
# The 100 halo-lists took 88.47655916213989 seconds to run
# The 100 halo-lists took 133.11920714378357 seconds to run
