# %%
from sim_pipeline.Halos.halos_plus_glass import run_halos_without_kde_by_multiprocessing
import numpy as np
from astropy.cosmology import FlatLambdaCDM

# %%
cosmo = FlatLambdaCDM(H0=70, Om0=0.3)

nk,ng = run_halos_without_kde_by_multiprocessing(n_iterations=50, sky_area=0.0001, samples_number=2,cosmo=cosmo,  m_min=1.5E+11, m_max=None, z_max=1.5)
# Out:
# The 50 halo-lists took 46.99708580970764 seconds to run

# %%
import seaborn as sns
import matplotlib.pyplot as plt

total_plot = sns.jointplot(x=nk, y=ng,kind='hex')
total_plot.plot_joint(sns.kdeplot, color="r", zorder=3, levels=5)
total_plot.ax_joint.set_xlabel('kappa', fontweight='bold')
total_plot.ax_joint.set_ylabel('gamma', fontweight='bold')
total_plot.fig.suptitle("Kappa and Gamma values without correction")
plt.show()

# %%
from sim_pipeline.Halos.halos_lens import HalosLens
from sim_pipeline.Halos.halos_plus_glass import run_certain_redshift_lensext_kde_by_multiprocessing
from astropy.cosmology import FlatLambdaCDM
cosmo = FlatLambdaCDM(H0=70, Om0=0.3)
distribution = run_certain_redshift_lensext_kde_by_multiprocessing(n_iterations=50, sky_area=0.0001, samples_number=2,cosmo=cosmo,  m_min=1.5E+11, m_max=None, z_max=1.5, zs=1.5, zd=0.5)

print(distribution)
# Out:
# The 50 halo-lists took 50.20884466171265 seconds to run
# [array([-0.03181777,  0.00138073]), array([-0.0375533 ,  0.00186584]), array([-0.03198993,  0.00160535]), array([-0.02692705,  0.00418736]), array([0.08938481, 0.03683057]), array([0.06071253, 0.00826358]), array([-0.01880079,  0.00847466]), array([-0.01520377,  0.0109968 ]), array([-0.00855835,  0.00471449]), array([0.00866532, 0.00342208]), array([-0.02022325,  0.00898746]), array([-0.01973661,  0.00580477]), array([0.03263329, 0.02459668]), array([-0.00567647,  0.00299877]), array([-0.02730661,  0.00451263]), array([-0.01284299,  0.0069285 ]), array([-0.0207218 ,  0.00759343]), array([-0.01503857,  0.00800965]), array([-0.01291381,  0.01261673]), array([-0.00215006,  0.01156788]), array([0.16270109, 0.03090476]), array([0.07247681, 0.01352226]), array([-0.01932404,  0.0078749 ]), array([-0.02492348,  0.00672642]), array([0.01780885, 0.01943538]), array([-0.00259895,  0.01345056]), array([-0.02351715,  0.00760476]), array([-0.0245036 ,  0.01261015]), array([0.00033737, 0.00193116]), array([0.01550606, 0.01885861]), array([-0.00298292,  0.00950722]), array([-0.01921496,  0.00645398]), array([-0.024861  ,  0.00449137]), array([-0.02752929,  0.00781731]), array([-0.00387642,  0.00487965]), array([-0.02540495,  0.01123077]), array([0.0429493 , 0.01033883]), array([-0.0096453 ,  0.00879142]), array([-0.00186604,  0.01483588]), array([-0.00358605,  0.01232757]), array([-0.03394856,  0.00381249]), array([-0.03144444,  0.00633758]), array([-0.01200015,  0.01250743]), array([0.01450171, 0.02930672]), array([-0.00051382,  0.01338704]), array([-0.01220964,  0.01163545]), array([-0.02350002,  0.00636702]), array([-0.02678693,  0.00433849]), array([-0.02703254,  0.00407416]), array([-0.03191332,  0.00313008]), array([-0.02933887,  0.00529072]), array([-0.02804252,  0.00556992]), array([-0.01640856,  0.00703848]), array([0.00273128, 0.01512519]), array([-0.0111022 ,  0.00996029]), array([-0.02686867,  0.00800691]), array([-0.02213371,  0.01668397]), array([-0.02364567,  0.00627952]), array([-0.02855173,  0.00355593]), array([-0.0237851 ,  0.00748736]), array([-0.03722742,  0.00147989]), array([-0.03712242,  0.00097455]), array([0.18859592, 0.01945581]), array([0.07890364, 0.01324234]), array([0.20254016, 0.04567454]), array([0.10532696, 0.06038208]), array([0.04374953, 0.02709102]), array([0.05156346, 0.0034702 ]), array([0.01465593, 0.01110174]), array([-0.01368259,  0.00559067]), array([0.58829822, 0.07895415]), array([0.67333215, 0.00778969]), array([-0.03761871,  0.0001325 ]), array([-0.0381026 ,  0.00012512]), array([-0.02715916,  0.00243075]), array([-0.00725189,  0.00995684]), array([-0.03596042,  0.00130762]), array([-0.03731123,  0.00203987]), array([0.01546972, 0.01875344]), array([0.0213765 , 0.01517307]), array([-0.00966311,  0.01010403]), array([-0.01407057,  0.01061214]), array([0.02441343, 0.00742251]), array([0.08402618, 0.00914395]), array([-0.03261638,  0.00058356]), array([-0.0275062 ,  0.00400513]), array([-0.01942581,  0.00283448]), array([-0.02260054,  0.00841245]), array([-0.03342217,  0.00337638]), array([-0.03270343,  0.00423082]), array([0.0183493 , 0.01244645]), array([0.03400886, 0.00605506]), array([-0.03294256,  0.00551097]), array([-0.03171695,  0.00490253]), array([-0.02544543,  0.00572093]), array([-0.01834137,  0.00661343]), array([0.00796162, 0.01197995]), array([0.0217601 , 0.00375807]), array([-0.02449567,  0.00589738]), array([-0.02993026,  0.00318472])]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

nk1 = [point[0] for point in distribution]
ng1 = [point[1] for point in distribution]

total_plot = sns.jointplot(x=nk1, y=ng1,kind='hex')
total_plot.plot_joint(sns.kdeplot, color="r", zorder=3, levels=5)
total_plot.ax_joint.set_xlabel('kappa', fontweight='bold')
total_plot.ax_joint.set_ylabel('gamma', fontweight='bold')
total_plot.fig.suptitle("Kappa and Gamma values with correction")
plt.show()

# %%
cosmo = FlatLambdaCDM(H0=70, Om0=0.3)

nk,ng = run_halos_without_kde_by_multiprocessing(n_iterations=70, sky_area=0.0001, samples_number=2,cosmo=cosmo,  m_min=5E+10, m_max=None, z_max=1.5)
import seaborn as sns
import matplotlib.pyplot as plt

total_plot = sns.jointplot(x=nk, y=ng,kind='hex')
total_plot.plot_joint(sns.kdeplot, color="r", zorder=3, levels=5)
total_plot.ax_joint.set_xlabel('kappa', fontweight='bold')
total_plot.ax_joint.set_ylabel('gamma', fontweight='bold')
total_plot.fig.suptitle("Kappa and Gamma values without correction")
plt.show()

from sim_pipeline.Halos.halos_plus_glass import run_certain_redshift_lensext_kde_by_multiprocessing
from astropy.cosmology import FlatLambdaCDM
cosmo = FlatLambdaCDM(H0=70, Om0=0.3)
distribution = run_certain_redshift_lensext_kde_by_multiprocessing(n_iterations=70, sky_area=0.0001, samples_number=2,cosmo=cosmo,  m_min=5E+10, m_max=None, z_max=1.5, zs=1.5, zd=0.5)

nk1 = [point[0] for point in distribution]
ng1 = [point[1] for point in distribution]

total_plot = sns.jointplot(x=nk1, y=ng1,kind='hex')
total_plot.plot_joint(sns.kdeplot, color="r", zorder=3, levels=5)
total_plot.ax_joint.set_xlabel('kappa', fontweight='bold')
total_plot.ax_joint.set_ylabel('gamma', fontweight='bold')
total_plot.fig.suptitle("Kappa and Gamma values with correction")
plt.show()
# Out:
# The 70 halo-lists took 92.80627465248108 seconds to run
# The 70 halo-lists took 104.07581615447998 seconds to run

# %%
print(distribution)

# %%
import pandas as pd

df1 = pd.DataFrame({'x': nk, 'y': ng, 'type': 'Without Correction'})
df2 = pd.DataFrame({'x': nk1, 'y': ng1, 'type': 'With LOS Correction'})

# Concatenate DataFrames
df_total = pd.concat([df1, df2], axis=0)

import seaborn as sns

sns.jointplot(data=df_total, x="x", y="y", hue="type", kind="kde")
plt.title('z_max=1.5, zs=1.5')
plt.show()

# %%
import pandas as pd
from sim_pipeline.Halos.halos_plus_glass import run_halos_without_kde_by_multiprocessing, run_certain_redshift_lensext_kde_by_multiprocessing
from astropy.cosmology import FlatLambdaCDM,default_cosmology
import seaborn as sns
import matplotlib.pyplot as plt

def plot_kappa_gamma(zs=1.5, zd=0.5, n_iterations=70, sky_area=0.0001, samples_number=2, m_min=5E+10, m_max=None):
    # Setup Cosmology
    cosmo = default_cosmology.get()
    # Without Correction
    nk, ng = run_halos_without_kde_by_multiprocessing(n_iterations=n_iterations, sky_area=sky_area, samples_number=samples_number, cosmo=cosmo, m_min=m_min, m_max=m_max, z_max=zs)
    nk_mean = sum(nk) / len(nk)
    nk = [item - nk_mean for item in nk]
    
    # With Correction
    distribution = run_certain_redshift_lensext_kde_by_multiprocessing(n_iterations=n_iterations, sky_area=sky_area, samples_number=samples_number, cosmo=cosmo, m_min=m_min, m_max=m_max, z_max=zs, zs=zs, zd=zd)
    nk1 = [point[0] for point in distribution]
    ng1 = [point[1] for point in distribution]
    nk1_mean = sum(nk1) / len(nk1)
    nk1 = [item - nk1_mean for item in nk1]
    
    
    # Combine Data for Joint KDE Plot
    df1 = pd.DataFrame({'x': nk, 'y': ng, 'type': 'Without Correction'})
    df2 = pd.DataFrame({'x': nk1, 'y': ng1, 'type': 'With LOS Correction'})
    df_total = pd.concat([df1, df2], axis=0)
    
    # Plotting
    sns.jointplot(data=df_total, x="x", y="y", hue="type", kind="kde")
    plt.title(f'zs={zs}, zd={zd}, mean=0')
    plt.show()

# To use the function:
plot_kappa_gamma(zs=2.5, zd=1.0)

plot_kappa_gamma(zs=3.5, zd=1.5)

plot_kappa_gamma(zs=1.5, zd=1.0)
# Out:
# The 70 halo-lists took 178.70486855506897 seconds to run
# The 70 halo-lists took 207.6863157749176 seconds to run
# The 70 halo-lists took 267.58870029449463 seconds to run
# The 70 halo-lists took 310.8471658229828 seconds to run
# The 70 halo-lists took 92.33722710609436 seconds to run
# The 70 halo-lists took 102.63829803466797 seconds to run

# %%
plot_kappa_gamma(zs=5.0, zd=4.5, m_min=5E+11)
# Out:
# The 70 halo-lists took 66.10033583641052 seconds to run
# The 70 halo-lists took 72.64736795425415 seconds to run

# %%
plot_kappa_gamma(zs=5.0, zd=4.8, m_min=5E+11)
# Out:
# The 70 halo-lists took 67.46072673797607 seconds to run
# The 70 halo-lists took 71.20068383216858 seconds to run

# %%
import pandas as pd
from sim_pipeline.Halos.halos_plus_glass import run_halos_without_kde_by_multiprocessing, run_certain_redshift_lensext_kde_by_multiprocessing
from astropy.cosmology import FlatLambdaCDM,default_cosmology
import seaborn as sns
import matplotlib.pyplot as plt

def plot_kappa_gamma2(zs=1.5, zd=0.5, n_iterations=500, sky_area=0.0001, samples_number=2, m_min=5E+11, m_max=None):
    # Setup Cosmology
    cosmo = default_cosmology.get()
    # Without Correction
    nk, ng = run_halos_without_kde_by_multiprocessing(n_iterations=n_iterations, sky_area=sky_area, samples_number=samples_number, cosmo=cosmo, m_min=m_min, m_max=m_max, z_max=zs,mass_sheet_correction=False)
    nk_mean = sum(nk) / len(nk)
    nk = [item - nk_mean for item in nk]
    
    # With Correction
    distribution = run_certain_redshift_lensext_kde_by_multiprocessing(n_iterations=n_iterations, sky_area=sky_area, samples_number=samples_number, cosmo=cosmo, m_min=m_min, m_max=m_max, z_max=zs, zs=zs, zd=zd,mass_sheet_correction=False)
    nk1 = [point[0] for point in distribution]
    ng1 = [point[1] for point in distribution]
    nk1_mean = sum(nk1) / len(nk1)
    nk1 = [item - nk1_mean for item in nk1]
    
    
    # Combine Data for Joint KDE Plot
    df1 = pd.DataFrame({'x': nk, 'y': ng, 'type': 'Without Correction'})
    df2 = pd.DataFrame({'x': nk1, 'y': ng1, 'type': 'With LOS Correction'})
    df_total = pd.concat([df1, df2], axis=0)
    
    # Plotting
    plot = sns.jointplot(data=df_total, x="x", y="y",  hue="type", kind="kde")
    plot.fig.suptitle(f"zs={zs}, zd={zd}, mean=0, without mass-sheet")

    plt.show()

# %%
plot_kappa_gamma2(zs=2.5, zd=1.0)

plot_kappa_gamma2(zs=3.5, zd=1.5)

plot_kappa_gamma2(zs=1.5, zd=1.0)
# Out:
# The 500 halo-lists took 311.47411727905273 seconds to run
# The 500 halo-lists took 323.6270844936371 seconds to run
# The 500 halo-lists took 363.81526136398315 seconds to run
# The 500 halo-lists took 386.6751170158386 seconds to run
# The 500 halo-lists took 238.8464469909668 seconds to run
# The 500 halo-lists took 240.95361518859863 seconds to run
